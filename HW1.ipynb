# %% [markdown]
# <a href="https://colab.research.google.com/github/prapakronmeesaii2006/Python-DataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ประภากร มีใส

# %%
print('673020045-9')
# Out:
# 673020045-9
